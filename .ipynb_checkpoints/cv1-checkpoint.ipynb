# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('6_26.jpg')
fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(im[:,:,0])
plt.subplot(222)
plt.imshow(im[:,:,1])
plt.subplot(223)
plt.imshow(im[:,:,2])
plt.subplot(224)
plt.imshow(im)
plt.show()

# %%
im = pltimg.imread('6_26.jpg')
fig = plt.figure()
plt.subplot(121)
plt.plot(im[:,1000,1])
plt.subplot(122)
plt.imshow(im)
plt.show()

# %%
plt.imshow(im[200:600, 900:1200])
plt.show()

# %%
fig = plt.figure(figsize=(15,10))
temp1 = im[:,:,0]
im[:,:,0] = im[:,:,1]
im[:,:,1] = im[:,:,2]
im[:,:,2] = temp1
plt.imshow(im[:,:,0])
plt.imshow(im[:,:,1])
plt.imshow(im[:,:,2])
plt.imshow(im)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-81e82241f31c> in <module>()
# ----> 1 fig = plt.figure(figsize=(15,10))
#       2 temp1 = im[:,:,0]
#       3 im[:,:,0] = im[:,:,1]
#       4 im[:,:,1] = im[:,:,2]
#       5 im[:,:,2] = temp1
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('6_26.jpg')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
im = pltimg.imread('6_26.jpg')
im[200:600, 1300:1600] = im[200:600, 900:1200]
plt.imshow(im)
plt.show()
